# %%
import pandas as pd
import numpy as np
import math

# Load the data
df = pd.read_csv('dea_data.csv')

# %%
# Separate control and treatment groups

control_cols = [col for col in df.columns if'Control' in col]
treatment_cols = [col for col in df.columns if'Treatment' in col]

# %%
# Calculate mean expression levels

df['Control Mean'] = df[control_cols].mean(axis=1)
df['Treatment Mean'] = df[treatment_cols].mean(axis=1)

# %%
# Compute log2 fold change
# Add a small constant to avoid log(0) issues

epsilon = 1e-10
df['log2FC'] = np.log2((df['Treatment Mean'] + epsilon) / (df['Control Mean'] + epsilon))

# %%
# Deterine status based on trushold

df['Status'] = 'Not Significant'
df.loc[df['log2FC'] >= 1, 'Status'] = 'Upregulated'
df.loc[df['log2FC'] <= -1, 'Status'] = 'Downregulated'

# %%
# Create the final output DataFrame with required columns

result_df = df[['Gene', 'Control Mean', 'Treatment Mean', 'log2FC', 'Status']]

# %%
# Display all results

print("Complete Differential Expression Analysis Results:")
print("=" * 100)
print(f"{'Gene':<10} {'Control Mean':<15} {'Treatment Mean':<15} {'Log2FC':<10} {'Status':<20}")
print("-" * 100)

for _, row in result_df.iterrows():
    print(f"{row['Gene']:<10} {row['Control Mean']:<15.2f} {row['Treatment Mean']:<15.2f} {row['log2FC']:<10.2f} {row['Status']:<20}")
# Out:
# Complete Differential Expression Analysis Results:
# ====================================================================================================
# Gene       Control Mean    Treatment Mean  Log2FC     Status
# ----------------------------------------------------------------------------------------------------
# Gene1      53.52           54.88           0.04       Not Significant
# Gene2      47.08           63.28           0.43       Not Significant
# Gene3      45.16           47.92           0.09       Not Significant
# Gene4      51.44           53.56           0.06       Not Significant
# Gene5      48.04           53.24           0.15       Not Significant
# Gene6      51.12           45.72           -0.16      Not Significant
# Gene7      48.36           45.00           -0.10      Not Significant
# Gene8      58.00           41.80           -0.47      Not Significant
# Gene9      57.80           50.56           -0.19      Not Significant
# Gene10     48.20           60.92           0.34       Not Significant
# Gene11     46.88           54.12           0.21       Not Significant
# Gene12     49.60           50.44           0.02       Not Significant
# Gene13     48.04           51.80           0.11       Not Significant
# Gene14     52.84           44.08           -0.26      Not Significant
# Gene15     53.64           47.68           -0.17      Not Significant
# Gene16     56.32           52.80           -0.09      Not Significant
# Gene17     59.32           52.56           -0.17      Not Significant
# Gene18     50.20           54.60           0.12       Not Significant
# Gene19     45.56           51.40           0.17       Not Significant
# Gene20     53.52           55.84           0.06       Not Significant
# Gene21     36.92           53.24           0.53       Not Significant
# Gene22     48.00           49.92           0.06       Not Significant
# Gene23     46.76           43.52           -0.10      Not Significant
# Gene24     55.52           48.88           -0.18      Not Significant
# Gene25     50.60           59.72           0.24       Not Significant
# Gene26     54.52           49.92           -0.13      Not Significant
# Gene27     58.56           39.40           -0.57      Not Significant
# Gene28     54.24           53.64           -0.02      Not Significant
# Gene29     45.36           52.36           0.21       Not Significant
# Gene30     54.04           50.24           -0.11      Not Significant
# Gene31     52.84           44.56           -0.25      Not Significant
# Gene32     48.56           56.28           0.21       Not Significant
# Gene33     50.24           47.28           -0.09      Not Significant
# Gene34     61.84           52.60           -0.23      Not Significant
# Gene35     48.04           58.80           0.29       Not Significant
# Gene36     51.24           50.52           -0.02      Not Significant
# Gene37     44.12           51.32           0.22       Not Significant
# Gene38     61.32           54.60           -0.17      Not Significant
# Gene39     48.16           51.84           0.11       Not Significant
# Gene40     47.80           56.00           0.23       Not Significant
# Gene41     42.04           51.76           0.30       Not Significant
# Gene42     48.28           46.12           -0.07      Not Significant
# Gene43     53.80           52.88           -0.02      Not Significant
# Gene44     61.68           56.56           -0.13      Not Significant
# Gene45     51.24           48.28           -0.09      Not Significant
# Gene46     50.16           47.60           -0.08      Not Significant
# Gene47     50.72           47.64           -0.09      Not Significant
# Gene48     49.40           47.84           -0.05      Not Significant
# Gene49     43.24           51.68           0.26       Not Significant
# Gene50     52.72           50.12           -0.07      Not Significant
# Gene51     44.56           47.00           0.08       Not Significant
# Gene52     49.64           51.36           0.05       Not Significant
# Gene53     58.68           43.44           -0.43      Not Significant
# Gene54     51.40           49.16           -0.06      Not Significant
# Gene55     43.52           49.12           0.17       Not Significant
# Gene56     52.96           38.68           -0.45      Not Significant
# Gene57     52.60           43.52           -0.27      Not Significant
# Gene58     50.36           52.88           0.07       Not Significant
# Gene59     57.96           51.40           -0.17      Not Significant
# Gene60     61.00           48.76           -0.32      Not Significant
# Gene61     60.32           56.76           -0.09      Not Significant
# Gene62     51.64           45.76           -0.17      Not Significant
# Gene63     44.52           38.48           -0.21      Not Significant
# Gene64     52.56           54.12           0.04       Not Significant
# Gene65     52.36           51.52           -0.02      Not Significant
# Gene66     53.44           55.56           0.06       Not Significant
# Gene67     50.60           53.28           0.07       Not Significant
# Gene68     53.04           52.28           -0.02      Not Significant
# Gene69     52.40           50.12           -0.06      Not Significant
# Gene70     56.00           52.08           -0.10      Not Significant
# Gene71     51.24           49.00           -0.06      Not Significant
# Gene72     52.92           50.80           -0.06      Not Significant
# Gene73     50.68           45.64           -0.15      Not Significant
# Gene74     40.72           58.36           0.52       Not Significant
# Gene75     59.76           48.88           -0.29      Not Significant
# Gene76     40.76           49.52           0.28       Not Significant
# Gene77     50.96           48.60           -0.07      Not Significant
# Gene78     60.12           50.96           -0.24      Not Significant
# Gene79     52.24           48.16           -0.12      Not Significant
# Gene80     41.36           43.24           0.06       Not Significant
# Gene81     48.76           57.68           0.24       Not Significant
# Gene82     50.48           56.24           0.16       Not Significant
# Gene83     56.40           58.92           0.06       Not Significant
# Gene84     56.92           53.92           -0.08      Not Significant
# Gene85     64.88           47.08           -0.46      Not Significant
# Gene86     44.92           56.12           0.32       Not Significant
# Gene87     55.56           46.08           -0.27      Not Significant
# Gene88     54.24           59.64           0.14       Not Significant
# Gene89     50.36           58.76           0.22       Not Significant
# Gene90     50.28           55.44           0.14       Not Significant
# Gene91     56.84           48.04           -0.24      Not Significant
# Gene92     50.24           42.76           -0.23      Not Significant
# Gene93     48.96           59.36           0.28       Not Significant
# Gene94     55.28           50.92           -0.12      Not Significant
# Gene95     54.92           50.24           -0.13      Not Significant
# Gene96     51.56           45.28           -0.19      Not Significant
# Gene97     49.32           52.36           0.09       Not Significant
# Gene98     45.40           64.40           0.50       Not Significant
# Gene99     58.08           55.60           -0.06      Not Significant
# Gene100    51.72           48.00           -0.11      Not Significant

# %%
# Summary statistics

print("\n" + "=" * 100)
print("SUMMARY STATISTICS:")
print(f"Total genes analyzed: {len(result_df)}")
print(f"Upregulated genes (Log2FC ≥ 1): {sum(result_df['Status'] == 'Upregulated')}")
print(f"Downregulated genes (Log2FC ≤ -1): {sum(result_df['Status'] == 'Downregulated')}")
print(f"Not significant genes: {sum(result_df['Status'] == 'Not significant')}")
# Out:
# ====================================================================================================
# SUMMARY STATISTICS:
# Total genes analyzed: 100
# Upregulated genes (Log2FC ≥ 1): 0
# Downregulated genes (Log2FC ≤ -1): 0
# Not significant genes: 0

# %%
# Show top differentially expressed genes

print("\n" + "=" * 100)
print("TOP 10 UPREGULATED GENES:")
top_upregulated = result_df[result_df['Status'] == 'Upregulated'].sort_values('log2FC', ascending=False).head(10)
print(top_upregulated.to_string(index=False))
# Out:
# ====================================================================================================
# TOP 10 UPREGULATED GENES:
# Empty DataFrame
# Columns: [Gene, Control Mean, Treatment Mean, log2FC, Status]
# Index: []

# %%
print("\n" + "=" * 100)
print("TOP 10 DOWNREGULATED GENES:")
top_downregulated = result_df[result_df['Status'] == 'Downregulated'].sort_values('log2FC', ascending=True).head(10)
print(top_downregulated.to_string(index=False))
# Out:
# ====================================================================================================
# TOP 10 DOWNREGULATED GENES:
# Empty DataFrame
# Columns: [Gene, Control Mean, Treatment Mean, log2FC, Status]
# Index: []

# %%
# Export to CSV for further analysis

result_df.to_csv('differential_expression_results.csv', index=False)
print("\nResults have been saved to 'differential_expression_results.csv'")
# Out:
# Results have been saved to 'differential_expression_results.csv'
